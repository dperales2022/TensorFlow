# %% [markdown]
# # 0. Import Data

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('insurance_claims.csv')

# %%
X = pd.get_dummies(df.drop(['fraud_reported', 'policy_number'], axis=1))
y = df['fraud_reported'].apply(lambda x: 1 if x=='Yes' else 0)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2)

# %% [markdown]
# # 1. Import Dependencies

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense
from sklearn.metrics import accuracy_score

# %% [markdown]
# # 2. Build and Compile Model

# %%
model = Sequential()
model.add(Dense(units=32, activation='relu', input_dim=len(X_train.columns)))
model.add(Dense(units=64, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='sgd', metrics='accuracy')

# %% [markdown]
# # 3. Fit, Predict and Evaluate

# %%
model.fit(X_train, y_train, epochs=20, batch_size=32)
# Out:
# Epoch 1/20
# 25/25 [==============================] - 0s 3ms/step - loss: nan - accuracy: 1.0000
# Epoch 2/20
# 25/25 [==============================] - 0s 3ms/step - loss: nan - accuracy: 1.0000
# Epoch 3/20
# 25/25 [==============================] - 0s 3ms/step - loss: nan - accuracy: 1.0000
# Epoch 4/20
# 25/25 [==============================] - 0s 3ms/step - loss: nan - accuracy: 1.0000
# Epoch 5/20
# 25/25 [==============================] - 0s 3ms/step - loss: nan - accuracy: 1.0000
# Epoch 6/20
# 25/25 [==============================] - 0s 3ms/step - loss: nan - accuracy: 1.0000
# Epoch 7/20
# 25/25 [==============================] - 0s 3ms/step - loss: nan - accuracy: 1.0000
# Epoch 8/20
# 25/25 [==============================] - 0s 3ms/step - loss: nan - accuracy: 1.0000
# Epoch 9/20
# 25/25 [==============================] - 0s 3ms/step - loss: nan - accuracy: 1.0000
# Epoch 10/20
# 25/25 [==============================] - 0s 3ms/step - loss: nan - accuracy: 1.0000
# Epoch 11/20
# 25/25 [==============================] - 0s 3ms/step - loss: nan - accuracy: 1.0000
# Epoch 12/20
# 25/25 [==============================] - 0s 3ms/step - loss: nan - accuracy: 1.0000
# Epoch 13/20
# 25/25 [==============================] - 0s 3ms/step - loss: nan - accuracy: 1.0000
# Epoch 14/20
# 25/25 [==============================] - 0s 3ms/step - loss: nan - accuracy: 1.0000
# Epoch 15/20
# 25/25 [==============================] - 0s 3ms/step - loss: nan - accuracy: 1.0000
# Epoch 16/20
# 25/25 [==============================] - 0s 3ms/step - loss: nan - accuracy: 1.0000
# Epoch 17/20
# 25/25 [==============================] - 0s 3ms/step - loss: nan - accuracy: 1.0000
# Epoch 18/20
# 25/25 [==============================] - 0s 3ms/step - loss: nan - accuracy: 1.0000
# Epoch 19/20
# 25/25 [==============================] - 0s 3ms/step - loss: nan - accuracy: 1.0000
# Epoch 20/20
# 25/25 [==============================] - 0s 3ms/step - loss: nan - accuracy: 1.0000

# %%
y_hat = model.predict(X_test)
y_hat = [0 if val < 0.5 else 1 for val in y_hat]

# %%
accuracy_score(y_test, y_hat)
# Out:
# 0.0

# %% [markdown]
# # 4. Saving and Reloading

# %%
model.save('tfmodel_insurance_claims')

# %%
del model

# %%
model = load_model('tfmodel_insurance_claims')
